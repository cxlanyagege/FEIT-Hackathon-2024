# %%
import numpy as np

# 读取 .npy 文件
spring = np.load('data/Residential_PV_profiles_Spring.npy')
summer = np.load('data/Residential_PV_profiles_Summer.npy')
autumn = np.load('data/Residential_PV_profiles_Autumn.npy')
winter = np.load('data/Residential_PV_profiles_Winter.npy')

# 打印数据
print(spring)
# Out:
# [[0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 1.6698000e-04 7.6474400e-03 3.6166700e-02
#   6.5153460e-02 1.1611410e-01 1.5725660e-01 2.1850286e-01 1.8858102e-01
#   2.5122988e-01 3.9706542e-01 2.8302182e-01 3.2182670e-01 3.4797492e-01
#   3.4750738e-01 2.5029480e-01 3.8447554e-01 3.3862434e-01 4.5694250e-01
#   2.9888440e-01 1.6750884e-01 2.7457292e-01 1.9462552e-01 1.1654822e-01
#   4.1743640e-02 1.6029560e-02 1.5361600e-03 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#   0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 4.2411400e-03
# ...
